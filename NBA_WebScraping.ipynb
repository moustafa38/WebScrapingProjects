# %% [markdown]
# ## Scrap th data

# %%
import csv
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Send a GET request to the website
url="https://www.basketball-reference.com/leagues/NBA_2022_per_game.html"
response = requests.get(url)

# %%
# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# %%
# Find the table containing the player stats
table = soup.find('table', {'id': 'per_game_stats'})

# %%
# Find all the rows in the table
rows = table.find_all('tr')

# %%
# Extract the data from each row and store it in a list
data_rows = []
for row in rows[1:]:
    cols = row.find_all('td')
    cols = [col.text.strip() for col in cols]
    data_rows.append(cols)

# %%
#convert list to dataframe and add columns names
column_names=['Player','Position','Age','Team','Games','Games Started','Minutes Played Per Game','Field Goals Per Game','Field Goal Attempts Per Game','Field Goal Percentage','3-Point Field Goals Per Game','3-Point Field Goal Attempts Per Game','3-Point Field Goal Percentage','2-Point Field Goals Per Game','2-Point Field Goal Attempts Per Game','2-Point Field Goal Percentage','Effective Field Goal Percentage','Free Throws Per Game','Free Throw Attempts Per Game','Free Throw Percentage','Offensive Rebounds Per Game','Defensive Rebounds Per Game','Total Rebounds Per Game','Assists Per Game','Steals Per Game','Blocks Per Game','Turnovers Per Game','Personal Fouls Per Game','Points Per Game']
df=pd.DataFrame(data_rows, columns=column_names)
df.head()
# Out:
#               Player Position Age Team Games Games Started  \
# 0   Precious Achiuwa        C  22  TOR    73            28
# 1       Steven Adams        C  28  MEM    76            75
# 2        Bam Adebayo        C  24  MIA    56            56
# 3       Santi Aldama       PF  21  MEM    32             0
# 4  LaMarcus Aldridge        C  36  BRK    47            12
#
#   Minutes Played Per Game Field Goals Per Game Field Goal Attempts Per Game  \
# 0                    23.6                  3.6                          8.3
# 1                    26.3                  2.8                          5.1
# 2                    32.6                  7.3                         13.0
# 3                    11.3                  1.7                          4.1
# 4                    22.3                  5.4                          9.7
#
#   Field Goal Percentage  ... Free Throw Percentage  \
# 0                  .439  ...                  .595
# 1                  .547  ...                  .543
# 2                  .557  ...                  .753
# 3                  .402  ...                  .625
# 4                  .550  ...                  .873
#
#   Offensive Rebounds Per Game Defensive Rebounds Per Game  \
# 0                         2.0                         4.5
# 1                         4.6                         5.4
# 2                         2.4                         7.6
# 3                         1.0                         1.7
# 4                         1.6                         3.9
#
#   Total Rebounds Per Game Assists Per Game Steals Per Game Blocks Per Game  \
# 0                     6.5              1.1             0.5             0.6
# 1                    10.0              3.4             0.9             0.8
# 2                    10.1              3.4             1.4             0.8
# 3                     2.7              0.7             0.2             0.3
# 4                     5.5              0.9             0.3             1.0
#
#   Turnovers Per Game Personal Fouls Per Game Points Per Game
# 0                1.2                     2.1             9.1
# 1                1.5                     2.0             6.9
# 2                2.6                     3.1            19.1
# 3                0.5                     1.1             4.1
# 4                0.9                     1.7            12.9
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Data Wrangling

# %%
#check for duplicated
df.duplicated().sum()
# Out:
# 29

# %%
#check for duplicated Player
df.Player.duplicated().sum()
# Out:
# 236

# %%
# remove duplicated player 
df.drop_duplicates(["Player"],inplace=True)
df.shape
# Out:
# (606, 29)

# %%
df.head()
# Out:
#               Player Position Age Team Games Games Started  \
# 0   Precious Achiuwa        C  22  TOR    73            28
# 1       Steven Adams        C  28  MEM    76            75
# 2        Bam Adebayo        C  24  MIA    56            56
# 3       Santi Aldama       PF  21  MEM    32             0
# 4  LaMarcus Aldridge        C  36  BRK    47            12
#
#   Minutes Played Per Game Field Goals Per Game Field Goal Attempts Per Game  \
# 0                    23.6                  3.6                          8.3
# 1                    26.3                  2.8                          5.1
# 2                    32.6                  7.3                         13.0
# 3                    11.3                  1.7                          4.1
# 4                    22.3                  5.4                          9.7
#
#   Field Goal Percentage  ... Free Throw Percentage  \
# 0                  .439  ...                  .595
# 1                  .547  ...                  .543
# 2                  .557  ...                  .753
# 3                  .402  ...                  .625
# 4                  .550  ...                  .873
#
#   Offensive Rebounds Per Game Defensive Rebounds Per Game  \
# 0                         2.0                         4.5
# 1                         4.6                         5.4
# 2                         2.4                         7.6
# 3                         1.0                         1.7
# 4                         1.6                         3.9
#
#   Total Rebounds Per Game Assists Per Game Steals Per Game Blocks Per Game  \
# 0                     6.5              1.1             0.5             0.6
# 1                    10.0              3.4             0.9             0.8
# 2                    10.1              3.4             1.4             0.8
# 3                     2.7              0.7             0.2             0.3
# 4                     5.5              0.9             0.3             1.0
#
#   Turnovers Per Game Personal Fouls Per Game Points Per Game
# 0                1.2                     2.1             9.1
# 1                1.5                     2.0             6.9
# 2                2.6                     3.1            19.1
# 3                0.5                     1.1             4.1
# 4                0.9                     1.7            12.9
#
# [5 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 606 entries, 0 to 841
# Data columns (total 29 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Player                                605 non-null    object
#  1   Position                              605 non-null    object
#  2   Age                                   605 non-null    object
#  3   Team                                  605 non-null    object
#  4   Games                                 605 non-null    object
#  5   Games Started                         605 non-null    object
#  6   Minutes Played Per Game               605 non-null    object
#  7   Field Goals Per Game                  605 non-null    object
#  8   Field Goal Attempts Per Game          605 non-null    object
#  9   Field Goal Percentage                 605 non-null    object
#  10  3-Point Field Goals Per Game          605 non-null    object
#  11  3-Point Field Goal Attempts Per Game  605 non-null    object
#  12  3-Point Field Goal Percentage         605 non-null    object
#  13  2-Point Field Goals Per Game          605 non-null    object
#  14  2-Point Field Goal Attempts Per Game  605 non-null    object
#  15  2-Point Field Goal Percentage         605 non-null    object
#  16  Effective Field Goal Percentage       605 non-null    object
#  17  Free Throws Per Game                  605 non-null    object
#  18  Free Throw Attempts Per Game          605 non-null    object
#  19  Free Throw Percentage                 605 non-null    object
#  20  Offensive Rebounds Per Game           605 non-null    object
#  21  Defensive Rebounds Per Game           605 non-null    object
#  22  Total Rebounds Per Game               605 non-null    object
#  23  Assists Per Game                      605 non-null    object
#  24  Steals Per Game                       605 non-null    object
#  25  Blocks Per Game                       605 non-null    object
#  26  Turnovers Per Game                    605 non-null    object
#  27  Personal Fouls Per Game               605 non-null    object
#  28  Points Per Game                       605 non-null    object
# dtypes: object(29)
# memory usage: 142.0+ KB

# %%
# convert columns to float
df[['Minutes Played Per Game','Field Goals Per Game','Field Goal Attempts Per Game','Field Goal Percentage','3-Point Field Goals Per Game','3-Point Field Goal Attempts Per Game','3-Point Field Goal Percentage','2-Point Field Goals Per Game','2-Point Field Goal Attempts Per Game','2-Point Field Goal Percentage','Effective Field Goal Percentage','Free Throws Per Game','Free Throw Attempts Per Game','Free Throw Percentage','Offensive Rebounds Per Game','Defensive Rebounds Per Game','Total Rebounds Per Game','Assists Per Game','Steals Per Game','Blocks Per Game','Turnovers Per Game','Personal Fouls Per Game','Points Per Game']]= df[['Minutes Played Per Game','Field Goals Per Game','Field Goal Attempts Per Game','Field Goal Percentage','3-Point Field Goals Per Game','3-Point Field Goal Attempts Per Game','3-Point Field Goal Percentage','2-Point Field Goals Per Game','2-Point Field Goal Attempts Per Game','2-Point Field Goal Percentage','Effective Field Goal Percentage','Free Throws Per Game','Free Throw Attempts Per Game','Free Throw Percentage','Offensive Rebounds Per Game','Defensive Rebounds Per Game','Total Rebounds Per Game','Assists Per Game','Steals Per Game','Blocks Per Game','Turnovers Per Game','Personal Fouls Per Game','Points Per Game']].apply(pd.to_numeric)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 606 entries, 0 to 841
# Data columns (total 29 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Player                                605 non-null    object
#  1   Position                              605 non-null    object
#  2   Age                                   605 non-null    object
#  3   Team                                  605 non-null    object
#  4   Games                                 605 non-null    object
#  5   Games Started                         605 non-null    object
#  6   Minutes Played Per Game               605 non-null    float64
#  7   Field Goals Per Game                  605 non-null    float64
#  8   Field Goal Attempts Per Game          605 non-null    float64
#  9   Field Goal Percentage                 596 non-null    float64
#  10  3-Point Field Goals Per Game          605 non-null    float64
#  11  3-Point Field Goal Attempts Per Game  605 non-null    float64
#  12  3-Point Field Goal Percentage         561 non-null    float64
#  13  2-Point Field Goals Per Game          605 non-null    float64
#  14  2-Point Field Goal Attempts Per Game  605 non-null    float64
#  15  2-Point Field Goal Percentage         589 non-null    float64
#  16  Effective Field Goal Percentage       596 non-null    float64
#  17  Free Throws Per Game                  605 non-null    float64
#  18  Free Throw Attempts Per Game          605 non-null    float64
#  19  Free Throw Percentage                 546 non-null    float64
#  20  Offensive Rebounds Per Game           605 non-null    float64
#  21  Defensive Rebounds Per Game           605 non-null    float64
#  22  Total Rebounds Per Game               605 non-null    float64
#  23  Assists Per Game                      605 non-null    float64
#  24  Steals Per Game                       605 non-null    float64
#  25  Blocks Per Game                       605 non-null    float64
#  26  Turnovers Per Game                    605 non-null    float64
#  27  Personal Fouls Per Game               605 non-null    float64
#  28  Points Per Game                       605 non-null    float64
# dtypes: float64(23), object(6)
# memory usage: 142.0+ KB

# %%
#remove null row
df = df[df['Player'].notna()]

# %% [markdown]
# ## Data Cleaning

# %%
#replace null values with zeros
df=df.replace(np.nan,0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 605 entries, 0 to 841
# Data columns (total 29 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Player                                605 non-null    object
#  1   Position                              605 non-null    object
#  2   Age                                   605 non-null    object
#  3   Team                                  605 non-null    object
#  4   Games                                 605 non-null    object
#  5   Games Started                         605 non-null    object
#  6   Minutes Played Per Game               605 non-null    float64
#  7   Field Goals Per Game                  605 non-null    float64
#  8   Field Goal Attempts Per Game          605 non-null    float64
#  9   Field Goal Percentage                 605 non-null    float64
#  10  3-Point Field Goals Per Game          605 non-null    float64
#  11  3-Point Field Goal Attempts Per Game  605 non-null    float64
#  12  3-Point Field Goal Percentage         605 non-null    float64
#  13  2-Point Field Goals Per Game          605 non-null    float64
#  14  2-Point Field Goal Attempts Per Game  605 non-null    float64
#  15  2-Point Field Goal Percentage         605 non-null    float64
#  16  Effective Field Goal Percentage       605 non-null    float64
#  17  Free Throws Per Game                  605 non-null    float64
#  18  Free Throw Attempts Per Game          605 non-null    float64
#  19  Free Throw Percentage                 605 non-null    float64
#  20  Offensive Rebounds Per Game           605 non-null    float64
#  21  Defensive Rebounds Per Game           605 non-null    float64
#  22  Total Rebounds Per Game               605 non-null    float64
#  23  Assists Per Game                      605 non-null    float64
#  24  Steals Per Game                       605 non-null    float64
#  25  Blocks Per Game                       605 non-null    float64
#  26  Turnovers Per Game                    605 non-null    float64
#  27  Personal Fouls Per Game               605 non-null    float64
#  28  Points Per Game                       605 non-null    float64
# dtypes: float64(23), object(6)
# memory usage: 141.8+ KB

# %%
#save the work
df.to_csv('nba_clean.csv',index=False)
